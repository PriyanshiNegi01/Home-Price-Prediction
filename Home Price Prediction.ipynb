# %% [markdown]
# # Home Price Prediction
# (Linear Regression Single Variable)

# %% [markdown]
# #### Sample problem of predicting home price in Monroe, New Jersey (USA)
#
# Below table represents current home prices in monroe township based on square feet area, New Jersey.
#
# ![image.png](attachment:image.png)
#
# **Problem Statement**: Given above data build a machine learning model that can predict home prices based on square feet area.

# %%
# importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("D:\Projects\ML\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# to draw the plots
# %matplotlib inline
plt.xlabel('area(sqr feet)')
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price,color='red',marker='+')

# %% [markdown]
# Observation: The distribution is suitable for a linear regression model

# %%
# create a linear regression object
reg = linear_model.LinearRegression()

# fit the data: training the linear regression model using the available database
reg.fit(df[['area']],df.price) 
# the first arg has to be like a 2D array so we supply a df which contains area only
# Out:
# LinearRegression()

# %% [markdown]
# #### (1) Predict price of a home with area = 3300 sqr feet

# %%
reg.predict([[3300]])
# Out:
# D:\Downloads\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %% [markdown]
# ### Working:
#
# #### y = m*x + b
# where 'm' is coefficient and 'b' is intercept
#
# When we train the linear regression object using the available dataset, the coefficient(slope, m) and intercept(b) are calculated.
#
# Home prices can be presented as following equation,
# <br>
# **home price = m * (area) + b**

# %%
# let's see the values
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# let's check the equation y = m*x + b
135.78767123*3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# So, now we know how the price was predicted.

# %% [markdown]
# #### (2) Predict price of a home with area = 5000 sqr feet

# %%
reg.predict([[5000]])
# Out:
# D:\Downloads\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# ### Visual Representation of the Linear Equation

# %%
# how the linear equation line looks like?
# %matplotlib inline
plt.xlabel('area(sqr feet)')
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price,color='red',marker='+')

# to plot the predicted prices
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %% [markdown]
# ## Generate CSV file with list of home price predictions

# %%
d = pd.read_csv("D:\\Projects\\ML\\areas.csv")
d.head(5)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
# predicting the prices for the dataframe containing areas and storing it in a variable
p = reg.predict(d)

# %%
# creating a new column in the original dataframe
d['prices'] = p

# %%
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
# exporting the values to a new prediction.csv file to avoid modifying the original file
d.to_csv("D:\Projects\ML\homepricesPrediction.csv",index = False)
